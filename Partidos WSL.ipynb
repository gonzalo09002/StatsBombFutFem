# %% [markdown]
# Temporada 19/20 de la WSL

# %%
import pandas as pd
wsl=pd.read_json('https://raw.githubusercontent.com/gonzalo09002/open-data/81bb27062e43874a1bdb72be9d243e93a8212dbc/data/matches/37/42.json')
wsl=wsl.drop(columns=['competition','season','metadata','competition_stage','stadium','referee'])
wsl.head(10)
# Out:
#    match_id  match_date      kick_off  \
# 0   2275038  2020-02-12  20:30:00.000
# 1   2275037  2020-02-02  15:00:00.000
# 2   2275027  2020-02-02  15:00:00.000
# 3   2275030  2020-02-23  15:00:00.000
# 4   2275054  2020-01-05  15:00:00.000
# 5   2275056  2019-11-17  16:00:00.000
# 6   2275057  2020-02-02  15:00:00.000
# 7   2275062  2020-02-13  20:00:00.000
# 8   2275072  2020-01-05  13:30:00.000
# 9   2275073  2020-02-12  20:30:00.000
#
#                                            home_team  \
# 0  {'home_team_id': 974, 'home_team_name': 'Readi...
# 1  {'home_team_id': 746, 'home_team_name': 'Manch...
# 2  {'home_team_id': 965, 'home_team_name': 'Brigh...
# 3  {'home_team_id': 965, 'home_team_name': 'Brigh...
# 4  {'home_team_id': 965, 'home_team_name': 'Brigh...
# 5  {'home_team_id': 966, 'home_team_name': 'Liver...
# 6  {'home_team_id': 971, 'home_team_name': 'Chels...
# 7  {'home_team_id': 966, 'home_team_name': 'Liver...
# 8  {'home_team_id': 971, 'home_team_name': 'Chels...
# 9  {'home_team_id': 749, 'home_team_name': 'Totte...
#
#                                            away_team  home_score  away_score  \
# 0  {'away_team_id': 972, 'away_team_name': 'West ...           2           0
# 1  {'away_team_id': 968, 'away_team_name': 'Arsen...           2           1
# 2  {'away_team_id': 967, 'away_team_name': 'Evert...           1           0
# 3  {'away_team_id': 749, 'away_team_name': 'Totte...           0           1
# 4  {'away_team_id': 966, 'away_team_name': 'Liver...           1           0
# 5  {'away_team_id': 967, 'away_team_name': 'Evert...           0           1
# 6  {'away_team_id': 972, 'away_team_name': 'West ...           8           0
# 7  {'away_team_id': 968, 'away_team_name': 'Arsen...           2           3
# 8  {'away_team_id': 974, 'away_team_name': 'Readi...           3           1
# 9  {'away_team_id': 967, 'away_team_name': 'Evert...           2           2
#
#   match_status                last_updated  match_week
# 0    available     2020-02-14T17:43:49.368          16
# 1    available     2020-02-04T17:25:33.263          14
# 2    available     2020-02-04T17:28:02.434          14
# 3    available     2020-02-26T15:02:00.122          17
# 4    available     2020-01-07T16:39:26.820          11
# 5    available  2019-12-16T23:09:16.168756           6
# 6    available     2020-02-03T21:07:52.701          14
# 7    available     2020-02-15T18:25:32.723          16
# 8    available     2020-01-06T18:39:35.098          11
# 9    available     2020-02-14T12:43:58.327          16
